# %%
# import the packages
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D
import mpl_toolkits.axisartist.floating_axes as floating_axes
import themepy
import pandas as pd

# %%
df = pd.read_excel('final_df 11-08-2022.xlsx')
df.head()
# Out:
#    Player ID  Understat_ID             Team First Name        Second Name  \
# 0         28          5543          Arsenal    Gabriel  Fernando de Jesus
# 1        283          1250        Liverpool    Mohamed              Salah
# 2        285          1791        Liverpool      Trent   Alexander-Arnold
# 3        318          8260  Manchester City     Erling            Haaland
# 4        306          2379  Manchester City       João            Cancelo
#
#            Web Name    Position  Price Change  Current Price  Selected By  \
# 0             Jesus     Forward           0.0            8.0         71.3
# 1             Salah  Midfielder           0.0           13.0         62.6
# 2  Alexander-Arnold    Defender           0.0            7.5         56.4
# 3           Haaland     Forward           0.1           11.6         55.5
# 4           Cancelo    Defender           0.0            7.0         45.0
#
# ...
